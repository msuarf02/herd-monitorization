# %%
# !pip install ultralytics
# !pip install clearml

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from ultralytics import YOLO

root = "/content/drive/MyDrive/TFG/animal-detection/"
dataset = "UAV_sheeps"
source = root +'Source/*'

# %%
model = YOLO(root +"YOLOv8/"+ dataset +"/yolov8m/weights/best.pt")

# %%
model.predict(source, save=True, save_conf=False, hide_labels=True, conf=0.5, project=root, name='YOLOv8/'+ dataset +'/Results')
